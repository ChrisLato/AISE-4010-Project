# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras_tuner import RandomSearch
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ### LSTM Model with Hyperparameter Tuning

# %%
# Load and preprocess the data
data = pd.read_csv("data/merged_data.csv")
data['DATE'] = pd.to_datetime(data['DATE'])
data.set_index('DATE', inplace=True)
data.sort_index(inplace=True)

# Drop Recession column for better results (will be used in classification model)
data = data.drop(columns=['Recession'], errors='ignore')

# Normalize the data
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data)

# Sliding window
def create_sequences(data, look_back):
    X, y = [], []
    for i in range(len(data) - look_back):
        X.append(data[i:i + look_back])
        y.append(data[i + look_back])
    return np.array(X), np.array(y)

look_back = 12  # Use the past 12 months to predict the next month
X, y = create_sequences(scaled_data, look_back)

# Define dividing point between training and testing datasets
split_date = pd.Timestamp('2005-01-01')

# Find the index closest to the split_date
split_index = data.index.get_indexer([split_date], method='nearest')[0]

# Adjust for the look-back period
adjusted_split_index = max(0, split_index - look_back)

# Split the data into training and testing sets based on the adjusted split index
X_train, X_test = X[:adjusted_split_index].astype('float32'), X[adjusted_split_index:].astype('float32')
y_train, y_test = y[:adjusted_split_index], y[adjusted_split_index:]

# Extract corresponding dates for y_test
test_dates = data.index[adjusted_split_index + look_back:]  # Adjust for the look-back

# Ensure the sequential split aligns correctly with the data
print(f"Training data: {X_train.shape}, {y_train.shape}")
print(f"Testing data: {X_test.shape}, {y_test.shape}")

# Build the LSTM model
def build_model(hp):
    model = Sequential()
    model.add(
        LSTM(
            units=hp.Int('units', min_value=100, max_value=256, step=32),
            activation='tanh',
            recurrent_activation='sigmoid',
            return_sequences=True,
            input_shape=(X_train.shape[1], X_train.shape[2])
        )
    )
    model.add(Dropout(hp.Float('dropout_rate', min_value=0.1, max_value=0.3, step=0.1)))
    model.add(
        LSTM(
            units=hp.Int('units', min_value=100, max_value=256, step=32),
            activation='tanh',
            recurrent_activation='sigmoid',
        )
    )
    model.add(Dropout(hp.Float('dropout_rate', min_value=0.1, max_value=0.3, step=0.1)))
    model.add(Dense(y_train.shape[1], activation='linear'))
    model.compile(
        optimizer=tf.keras.optimizers.Adam(hp.Float('learning_rate', min_value=1e-5, max_value=1e-3, sampling='log')),
        loss='mse',
        metrics=['mae']
    )
    return model

# Hyperparameter tuning 
tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=100,
    executions_per_trial=1,
    directory='lstm_tuning',
    project_name='lstm_prediction_update'
)

# Search for the best hyperparameters
tuner.search(
    X_train, y_train,
    epochs=100, 
    validation_data=(X_test, y_test), 
    batch_size=16, verbose=1, )

# Get the best hyperparameters and model
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Optimal number of units: {best_hps.get('units')}")
print(f"Optimal dropout rate: {best_hps.get('dropout_rate')}")
print(f"Optimal learning rate: {best_hps.get('learning_rate')}")

# Train the best model with Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=15,  # Stop after 15 epochs with no improvement
    restore_best_weights=True  # Restore the weights of the best model
)

best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(
    X_train, y_train, 
    epochs=200, 
    validation_data=(X_test, y_test), 
    batch_size=32, 
    callbacks=[early_stopping],  
    verbose=1
)

# Plot training and validation loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs', fontsize=16)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# Evaluate the model
test_loss, test_mae = best_model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test MAE: {test_mae}")

# Save the trained model
best_model.save("best_lstm_model_update.h5")

# Predict and inverse transform the results
predictions = best_model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
y_test_inverse = scaler.inverse_transform(y_test)

# Save predictions to a CSV file
predicted_df = pd.DataFrame(y_test, index=test_dates, columns=data.columns)
predicted_df.to_csv("data/LSTM_predicted_values.csv")

# Plot actual vs predicted values for each feature
num_features = y_test.shape[1]

plt.figure(figsize=(18, num_features * 4))  
for i in range(num_features):
    plt.subplot(num_features, 1, i + 1)
    plt.plot(test_dates, y_test_inverse[:, i], label=f'Actual {data.columns[i]}', color='blue', linewidth=2)
    plt.plot(test_dates, predictions[:, i], label=f'Predicted {data.columns[i]}', color='orange', linewidth=2)
    plt.title(f"Actual vs. Predicted - {data.columns[i]}", fontsize=16)
    plt.xlabel("Date", fontsize=12)
    plt.ylabel("Value", fontsize=12)
    plt.legend(fontsize=10)
    plt.grid()

plt.tight_layout(pad=3.0)  
plt.show()

best_model.summary()
# Out:
# Trial 100 Complete [00h 00m 27s]
# val_loss: 0.005570669658482075
#
# Best val_loss So Far: 0.00394898746162653
# Total elapsed time: 03h 05m 31s
# Optimal number of units: 164
# Optimal dropout rate: 0.1
# Optimal learning rate: 0.0009499173325705382
# Epoch 1/200
# 14/14 [==============================] - 2s 42ms/step - loss: 0.0526 - mae: 0.1747 - val_loss: 0.0233 - val_mae: 0.1244
# Epoch 2/200
# 14/14 [==============================] - 0s 16ms/step - loss: 0.0131 - mae: 0.0856 - val_loss: 0.0100 - val_mae: 0.0754
# Epoch 3/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0098 - mae: 0.0727 - val_loss: 0.0089 - val_mae: 0.0644
# Epoch 4/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0087 - mae: 0.0671 - val_loss: 0.0081 - val_mae: 0.0632
# Epoch 5/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0076 - mae: 0.0622 - val_loss: 0.0084 - val_mae: 0.0628
# Epoch 6/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0073 - mae: 0.0612 - val_loss: 0.0079 - val_mae: 0.0596
# Epoch 7/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0071 - mae: 0.0595 - val_loss: 0.0069 - val_mae: 0.0551
# Epoch 8/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0068 - mae: 0.0583 - val_loss: 0.0073 - val_mae: 0.0571
# Epoch 9/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0066 - mae: 0.0572 - val_loss: 0.0068 - val_mae: 0.0541
# Epoch 10/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0065 - mae: 0.0565 - val_loss: 0.0080 - val_mae: 0.0625
# Epoch 11/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0063 - mae: 0.0553 - val_loss: 0.0067 - val_mae: 0.0533
# Epoch 12/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0063 - mae: 0.0557 - val_loss: 0.0076 - val_mae: 0.0607
# Epoch 13/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0059 - mae: 0.0538 - val_loss: 0.0067 - val_mae: 0.0542
# Epoch 14/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0061 - mae: 0.0548 - val_loss: 0.0082 - val_mae: 0.0622
# Epoch 15/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0060 - mae: 0.0543 - val_loss: 0.0064 - val_mae: 0.0532
# Epoch 16/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0055 - mae: 0.0524 - val_loss: 0.0069 - val_mae: 0.0568
# Epoch 17/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0054 - mae: 0.0516 - val_loss: 0.0067 - val_mae: 0.0554
# Epoch 18/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0053 - mae: 0.0513 - val_loss: 0.0063 - val_mae: 0.0519
# Epoch 19/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0055 - mae: 0.0521 - val_loss: 0.0063 - val_mae: 0.0532
# Epoch 20/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0053 - mae: 0.0514 - val_loss: 0.0069 - val_mae: 0.0571
# Epoch 21/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0052 - mae: 0.0501 - val_loss: 0.0061 - val_mae: 0.0519
# Epoch 22/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0051 - mae: 0.0497 - val_loss: 0.0064 - val_mae: 0.0525
# Epoch 23/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0051 - mae: 0.0503 - val_loss: 0.0058 - val_mae: 0.0488
# Epoch 24/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0051 - mae: 0.0511 - val_loss: 0.0068 - val_mae: 0.0570
# Epoch 25/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0050 - mae: 0.0491 - val_loss: 0.0066 - val_mae: 0.0554
# Epoch 26/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0049 - mae: 0.0488 - val_loss: 0.0066 - val_mae: 0.0544
# Epoch 27/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0049 - mae: 0.0494 - val_loss: 0.0059 - val_mae: 0.0494
# Epoch 28/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0048 - mae: 0.0482 - val_loss: 0.0057 - val_mae: 0.0490
# Epoch 29/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0048 - mae: 0.0490 - val_loss: 0.0073 - val_mae: 0.0592
# Epoch 30/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0053 - mae: 0.0516 - val_loss: 0.0065 - val_mae: 0.0538
# Epoch 31/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0050 - mae: 0.0498 - val_loss: 0.0058 - val_mae: 0.0489
# Epoch 32/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0046 - mae: 0.0471 - val_loss: 0.0068 - val_mae: 0.0576
# Epoch 33/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0047 - mae: 0.0474 - val_loss: 0.0060 - val_mae: 0.0498
# Epoch 34/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0045 - mae: 0.0465 - val_loss: 0.0059 - val_mae: 0.0491
# Epoch 35/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0046 - mae: 0.0465 - val_loss: 0.0064 - val_mae: 0.0535
# Epoch 36/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0045 - mae: 0.0472 - val_loss: 0.0059 - val_mae: 0.0494
# Epoch 37/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0046 - mae: 0.0472 - val_loss: 0.0065 - val_mae: 0.0541
# Epoch 38/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0046 - mae: 0.0474 - val_loss: 0.0062 - val_mae: 0.0519
# Epoch 39/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0043 - mae: 0.0456 - val_loss: 0.0053 - val_mae: 0.0454
# Epoch 40/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0044 - mae: 0.0455 - val_loss: 0.0055 - val_mae: 0.0468
# Epoch 41/200
# 14/14 [==============================] - 0s 8ms/step - loss: 0.0042 - mae: 0.0452 - val_loss: 0.0060 - val_mae: 0.0505
# Epoch 42/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0045 - mae: 0.0465 - val_loss: 0.0055 - val_mae: 0.0476
# Epoch 43/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0043 - mae: 0.0463 - val_loss: 0.0054 - val_mae: 0.0464
# Epoch 44/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0043 - mae: 0.0457 - val_loss: 0.0052 - val_mae: 0.0444
# Epoch 45/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0042 - mae: 0.0448 - val_loss: 0.0052 - val_mae: 0.0449
# Epoch 46/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0041 - mae: 0.0451 - val_loss: 0.0052 - val_mae: 0.0451
# Epoch 47/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0041 - mae: 0.0443 - val_loss: 0.0053 - val_mae: 0.0460
# Epoch 48/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0040 - mae: 0.0441 - val_loss: 0.0054 - val_mae: 0.0462
# Epoch 49/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0039 - mae: 0.0435 - val_loss: 0.0050 - val_mae: 0.0433
# Epoch 50/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0038 - mae: 0.0431 - val_loss: 0.0050 - val_mae: 0.0430
# Epoch 51/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0041 - mae: 0.0442 - val_loss: 0.0051 - val_mae: 0.0432
# Epoch 52/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0038 - mae: 0.0428 - val_loss: 0.0052 - val_mae: 0.0448
# Epoch 53/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0038 - mae: 0.0429 - val_loss: 0.0052 - val_mae: 0.0452
# Epoch 54/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0037 - mae: 0.0422 - val_loss: 0.0051 - val_mae: 0.0440
# Epoch 55/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0037 - mae: 0.0419 - val_loss: 0.0053 - val_mae: 0.0451
# Epoch 56/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0037 - mae: 0.0421 - val_loss: 0.0053 - val_mae: 0.0446
# Epoch 57/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0038 - mae: 0.0432 - val_loss: 0.0054 - val_mae: 0.0465
# Epoch 58/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - mae: 0.0413 - val_loss: 0.0051 - val_mae: 0.0439
# Epoch 59/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0035 - mae: 0.0423 - val_loss: 0.0053 - val_mae: 0.0457
# Epoch 60/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0039 - mae: 0.0434 - val_loss: 0.0052 - val_mae: 0.0450
# Epoch 61/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0038 - mae: 0.0427 - val_loss: 0.0050 - val_mae: 0.0425
# Epoch 62/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0037 - mae: 0.0427 - val_loss: 0.0055 - val_mae: 0.0480
# Epoch 63/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0036 - mae: 0.0419 - val_loss: 0.0050 - val_mae: 0.0424
# Epoch 64/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0036 - mae: 0.0413 - val_loss: 0.0052 - val_mae: 0.0448
# Epoch 65/200
# 14/14 [==============================] - 0s 12ms/step - loss: 0.0037 - mae: 0.0425 - val_loss: 0.0051 - val_mae: 0.0435
# Epoch 66/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - mae: 0.0415 - val_loss: 0.0051 - val_mae: 0.0435
# Epoch 67/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0036 - mae: 0.0412 - val_loss: 0.0047 - val_mae: 0.0400
# Epoch 68/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0035 - mae: 0.0405 - val_loss: 0.0050 - val_mae: 0.0427
# Epoch 69/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0036 - mae: 0.0416 - val_loss: 0.0048 - val_mae: 0.0411
# Epoch 70/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0401 - val_loss: 0.0049 - val_mae: 0.0420
# Epoch 71/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0034 - mae: 0.0398 - val_loss: 0.0047 - val_mae: 0.0403
# Epoch 72/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0033 - mae: 0.0393 - val_loss: 0.0050 - val_mae: 0.0434
# Epoch 73/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0397 - val_loss: 0.0049 - val_mae: 0.0424
# Epoch 74/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0405 - val_loss: 0.0053 - val_mae: 0.0443
# Epoch 75/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0409 - val_loss: 0.0054 - val_mae: 0.0460
# Epoch 76/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0040 - mae: 0.0437 - val_loss: 0.0050 - val_mae: 0.0430
# Epoch 77/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0034 - mae: 0.0407 - val_loss: 0.0053 - val_mae: 0.0467
# Epoch 78/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0033 - mae: 0.0392 - val_loss: 0.0049 - val_mae: 0.0416
# Epoch 79/200
# 14/14 [==============================] - 0s 13ms/step - loss: 0.0031 - mae: 0.0383 - val_loss: 0.0051 - val_mae: 0.0447
# Epoch 80/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0403 - val_loss: 0.0049 - val_mae: 0.0419
# Epoch 81/200
# 14/14 [==============================] - 0s 11ms/step - loss: 0.0033 - mae: 0.0395 - val_loss: 0.0051 - val_mae: 0.0440
# Epoch 82/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0402 - val_loss: 0.0055 - val_mae: 0.0491
# Epoch 83/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0402 - val_loss: 0.0055 - val_mae: 0.0485
# Epoch 84/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0406 - val_loss: 0.0050 - val_mae: 0.0427
# Epoch 85/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0386 - val_loss: 0.0045 - val_mae: 0.0390
# Epoch 86/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0033 - mae: 0.0394 - val_loss: 0.0049 - val_mae: 0.0424
# Epoch 87/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0032 - mae: 0.0384 - val_loss: 0.0047 - val_mae: 0.0406
# Epoch 88/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0389 - val_loss: 0.0046 - val_mae: 0.0399
# Epoch 89/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0387 - val_loss: 0.0051 - val_mae: 0.0458
# Epoch 90/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0032 - mae: 0.0391 - val_loss: 0.0049 - val_mae: 0.0430
# Epoch 91/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0032 - mae: 0.0390 - val_loss: 0.0047 - val_mae: 0.0421
# Epoch 92/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0381 - val_loss: 0.0049 - val_mae: 0.0413
# Epoch 93/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0034 - mae: 0.0396 - val_loss: 0.0051 - val_mae: 0.0431
# Epoch 94/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0385 - val_loss: 0.0052 - val_mae: 0.0453
# Epoch 95/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0392 - val_loss: 0.0047 - val_mae: 0.0418
# Epoch 96/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0033 - mae: 0.0391 - val_loss: 0.0049 - val_mae: 0.0419
# Epoch 97/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0032 - mae: 0.0384 - val_loss: 0.0046 - val_mae: 0.0391
# Epoch 98/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0381 - val_loss: 0.0053 - val_mae: 0.0461
# Epoch 99/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0030 - mae: 0.0370 - val_loss: 0.0046 - val_mae: 0.0399
# Epoch 100/200
# 14/14 [==============================] - 0s 9ms/step - loss: 0.0032 - mae: 0.0384 - val_loss: 0.0047 - val_mae: 0.0410
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0045 - mae: 0.0390
# Test Loss: 0.004522388800978661
# Test MAE: 0.03900410607457161
# 7/7 [==============================] - 0s 3ms/step
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 12, 164)           112832
#
#  dropout_2 (Dropout)         (None, 12, 164)           0
#
#  lstm_3 (LSTM)               (None, 164)               215824
#
#  dropout_3 (Dropout)         (None, 164)               0
#
#  dense_1 (Dense)             (None, 7)                 1155
#
# =================================================================
# Total params: 329,811
# Trainable params: 329,811
# Non-trainable params: 0
# _________________________________________________________________
